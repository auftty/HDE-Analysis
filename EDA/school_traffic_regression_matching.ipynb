# %% [markdown]
# # Влияние близости школ: регрессия и парные сравнения
#
# Цель: более строго проверить гипотезу, что у магазинов рядом со школами
# - **выше пешеходный трафик**,
# - **ниже средний чек** (как минимум в части сегментов).
#
# В этом ноутбуке:
# 1. Готовим признаки и фильтруем данные.
# 2. Строим две линейные регрессии (трафик и чек).
# 3. Делаем парные сравнения на уровне (НП, размер магазина).

# %%
import pandas as pd
import numpy as np
from pathlib import Path

input_path = Path('Х5_with_region_index_2024_population_patched_with_flags.xlsx')
df = pd.read_excel(input_path)
print('Размер исходного датафрейма:', df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 from pathlib import Path
#       5 input_path = Path('Х5_with_region_index_2024_population_patched_with_flags.xlsx')
# ----> 6 df = pd.read_excel(input_path)
#       7 print('Размер исходного датафрейма:', df.shape)
#       8 df.head()
#
# File c:\Users\Daria\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\Daria\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\Users\Daria\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\Users\Daria\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Х5_with_region_index_2024_population_patched_with_flags.xlsx'

# %% [markdown]
# ## Подготовка признаков
#
# Фильтруем только нормальные наблюдения и заводим нужные признаки: has_school, size_group, population, ria_index.

# %%
col_np = 'Населенный пункт'
col_region = 'Регион'
col_index = 'Индекс_РИА_2024'
col_is_season = 'is_season'
col_traffic_flag = 'traffic_flag'
col_pedestrian = 'Трафик пеший, в час'
col_check = 'Средний чек'
col_schools = 'Школы (300 м)'
col_size_cat = 'Торговая площадь, категориальный'

df[col_index] = pd.to_numeric(df[col_index], errors='coerce')
df[col_pedestrian] = pd.to_numeric(df[col_pedestrian], errors='coerce')
df[col_check] = pd.to_numeric(df[col_check], errors='coerce')
df[col_schools] = pd.to_numeric(df[col_schools], errors='coerce').fillna(0)

df['has_school'] = df[col_schools] > 0

size_map = {
    'Маленький': 'small',
    'Средний': 'medium',
    'Большой': 'large_plus',
    'Очень большой': 'large_plus',
}
df['size_group'] = df[col_size_cat].map(size_map)

# ищем колонку с численностью населения
pop_col = None
for c in df.columns:
    name = str(c)
    if 'числен' in name.lower() and 'насел' in name.lower():
        pop_col = c
        break
print('Колонка с населением:', pop_col)

if pop_col is not None:
    df[pop_col] = pd.to_numeric(df[pop_col], errors='coerce')
    df['population'] = df[pop_col]
else:
    df['population'] = np.nan

mask = (
    (df[col_is_season] == 1)
    & (df[col_traffic_flag] == 1)
    & (df[col_pedestrian] > 0)
    & df[col_index].notna()
    & df['size_group'].notna()
)

base_df = df[mask].copy()
print('Размер base_df после фильтрации:', base_df.shape)
base_df[[col_np, col_region, col_pedestrian, col_check, col_index, 'population', 'has_school', 'size_group']].head()
# Out:
# Колонка с населением: Численность населения
# Размер base_df после фильтрации: (60395, 24)
#                          Населенный пункт           Регион  \
# 3   1-го отделения совхоза "Масловский" п  Воронежская обл
# 4   1-го отделения совхоза "Масловский" п  Воронежская обл
# 10  1-го отделения совхоза "Масловский" п  Воронежская обл
# 13                            1-я Моква д      Курская обл
# 15                            1-я Моква д      Курская обл
#
#     Трафик пеший, в час  Средний чек  Индекс_РИА_2024  population  has_school  \
# 3             89.857143  1119.028697            61.98        3827       False
# 4             89.857143  1112.584778            61.98        3827       False
# 10            89.857143  1275.068118            61.98        3827       False
# 13            95.666667   683.123700            50.02         500        True
# 15            95.666667   687.641711            50.02         500        True
#
#    size_group
# 3      medium
# 4      medium
# 10     medium
# 13     medium
# 15     medium

# %% [markdown]
# ## Подготовка данных для регрессии
#
# Переименуем ключевые переменные и добавим логарифмы.

# %%
reg_df = base_df.copy()
reg_df = reg_df.rename(columns={
    col_np: 'np_name',
    col_region: 'region',
    col_pedestrian: 'traffic_ped',
    col_check: 'avg_check',
    col_index: 'ria_index',
})

# убираем строки без населения, если оно есть
if reg_df['population'].notna().any():
    reg_df = reg_df[reg_df['population'].notna()].copy()

reg_df = reg_df[(reg_df['traffic_ped'] > 0) & (reg_df['avg_check'] > 0)].copy()
reg_df['log_traffic'] = np.log(reg_df['traffic_ped'])
reg_df['log_check'] = np.log(reg_df['avg_check'])
reg_df['log_population'] = np.log(reg_df['population'].replace({0: np.nan}))

print('Размер reg_df для регрессии:', reg_df.shape)
reg_df[['np_name', 'region', 'traffic_ped', 'avg_check', 'ria_index', 'population', 'has_school', 'size_group']].head()
# Out:
# Размер reg_df для регрессии: (60392, 27)
#                                   np_name           region  traffic_ped  \
# 3   1-го отделения совхоза "Масловский" п  Воронежская обл    89.857143
# 4   1-го отделения совхоза "Масловский" п  Воронежская обл    89.857143
# 10  1-го отделения совхоза "Масловский" п  Воронежская обл    89.857143
# 13                            1-я Моква д      Курская обл    95.666667
# 15                            1-я Моква д      Курская обл    95.666667
#
#       avg_check  ria_index  population  has_school size_group
# 3   1119.028697      61.98        3827       False     medium
# 4   1112.584778      61.98        3827       False     medium
# 10  1275.068118      61.98        3827       False     medium
# 13   683.123700      50.02         500        True     medium
# 15   687.641711      50.02         500        True     medium

# %% [markdown]
# ## Линейная регрессия: трафик

# %%
import statsmodels.formula.api as smf

traffic_model = smf.ols(
    formula='log_traffic ~ has_school + C(size_group) + log_population + ria_index + C(region)',
    data=reg_df,
).fit()

print(traffic_model.summary().tables[1])
print('\nКоэффициент has_school по трафику (лог):', traffic_model.params.get('has_school[T.True]', np.nan))
# Out:
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    3.5933      0.064     56.548      0.000       3.469       3.718
# has_school[T.True]                                           0.0959      0.005     20.560      0.000       0.087       0.105
# C(size_group)[T.medium]                                     -0.1144      0.005    -21.541      0.000      -0.125      -0.104
# C(size_group)[T.small]                                      -0.1168      0.006    -18.209      0.000      -0.129      -0.104
# C(region)[T.Алтай Респ]                                      1.0392      0.092     11.256      0.000       0.858       1.220
# C(region)[T.Алтайский край]                                  0.5412      0.032     16.775      0.000       0.478       0.604
# C(region)[T.Архангельская обл]                               0.1500      0.038      3.938      0.000       0.075       0.225
# C(region)[T.Астраханская обл]                                0.0721      0.038      1.922      0.055      -0.001       0.146
# C(region)[T.Башкортостан Респ]                              -0.1827      0.014    -13.386      0.000      -0.209      -0.156
# C(region)[T.Белгородская обл]                               -0.1787      0.022     -8.219      0.000      -0.221      -0.136
# C(region)[T.Брянская обл]                                    0.1460      0.032      4.577      0.000       0.083       0.209
# C(region)[T.Владимирская обл]                                0.0156      0.026      0.594      0.552      -0.036       0.067
# C(region)[T.Волгоградская обл]                               0.0261      0.023      1.131      0.258      -0.019       0.071
# C(region)[T.Вологодская обл]                                 0.0070      0.027      0.254      0.799      -0.047       0.061
# C(region)[T.Воронежская обл]                                -0.1260      0.017     -7.451      0.000      -0.159      -0.093
# C(region)[T.Еврейская Аобл]                                  1.0689      0.231      4.624      0.000       0.616       1.522
# C(region)[T.Забайкальский край]                              0.6269      0.064      9.863      0.000       0.502       0.751
# C(region)[T.Ивановская обл]                                  0.2343      0.036      6.505      0.000       0.164       0.305
# C(region)[T.Иркутская обл]                                   0.4954      0.030     16.646      0.000       0.437       0.554
# C(region)[T.Кабардино-Балкарская Респ]                       0.0924      0.092      1.005      0.315      -0.088       0.273
# C(region)[T.Калининградская обл]                             0.1637      0.035      4.719      0.000       0.096       0.232
# C(region)[T.Калмыкия Респ]                                   0.2550      0.071      3.571      0.000       0.115       0.395
# C(region)[T.Калужская обл]                                   0.0095      0.027      0.345      0.730      -0.044       0.063
# C(region)[T.Карачаево-Черкесская Респ]                       0.2391      0.075      3.197      0.001       0.093       0.386
# C(region)[T.Карелия Респ]                                    0.2569      0.043      6.014      0.000       0.173       0.341
# C(region)[T.Кемеровская область - Кузбасс обл]               0.4116      0.024     16.987      0.000       0.364       0.459
# C(region)[T.Кировская обл]                                   0.2818      0.032      8.720      0.000       0.218       0.345
# C(region)[T.Коми Респ]                                       0.1502      0.036      4.180      0.000       0.080       0.221
# C(region)[T.Костромская обл]                                 0.1869      0.046      4.107      0.000       0.098       0.276
# C(region)[T.Краснодарский край]                             -0.3701      0.011    -32.371      0.000      -0.392      -0.348
# C(region)[T.Красноярский край]                               0.2339      0.021     11.020      0.000       0.192       0.275
# C(region)[T.Курганская обл]                                 -0.0694      0.049     -1.420      0.156      -0.165       0.026
# C(region)[T.Курская обл]                                    -0.0307      0.029     -1.078      0.281      -0.087       0.025
# C(region)[T.Ленинградская обл]                              -0.2119      0.017    -12.646      0.000      -0.245      -0.179
# C(region)[T.Липецкая обл]                                   -0.0405      0.022     -1.837      0.066      -0.084       0.003
# C(region)[T.Марий Эл Респ]                                   0.2221      0.043      5.159      0.000       0.138       0.306
# C(region)[T.Мордовия Респ]                                   0.1687      0.042      3.973      0.000       0.085       0.252
# C(region)[T.Москва г]                                       -0.3400      0.023    -14.931      0.000      -0.385      -0.295
# C(region)[T.Московская обл]                                 -0.2529      0.015    -16.795      0.000      -0.282      -0.223
# C(region)[T.Мурманская обл]                                  0.0297      0.031      0.966      0.334      -0.031       0.090
# C(region)[T.Нижегородская обл]                              -0.2110      0.013    -16.502      0.000      -0.236      -0.186
# C(region)[T.Новгородская обл]                                0.2060      0.041      4.980      0.000       0.125       0.287
# C(region)[T.Новосибирская обл]                              -0.0614      0.018     -3.487      0.000      -0.096      -0.027
# C(region)[T.Омская обл]                                      0.0016      0.029      0.053      0.958      -0.056       0.059
# C(region)[T.Оренбургская обл]                               -0.0459      0.023     -2.032      0.042      -0.090      -0.002
# C(region)[T.Орловская обл]                                   0.1819      0.039      4.648      0.000       0.105       0.259
# C(region)[T.Пензенская обл]                                  0.0154      0.032      0.475      0.635      -0.048       0.079
# C(region)[T.Пермский край]                                  -0.0557      0.015     -3.810      0.000      -0.084      -0.027
# C(region)[T.Приморский край]                                -0.4959      0.047    -10.547      0.000      -0.588      -0.404
# C(region)[T.Псковская обл]                                   0.2828      0.042      6.719      0.000       0.200       0.365
# C(region)[T.Ростовская обл]                                 -0.1978      0.012    -17.094      0.000      -0.221      -0.175
# C(region)[T.Рязанская обл]                                   0.0936      0.028      3.359      0.001       0.039       0.148
# C(region)[T.Самарская обл]                                  -0.1521      0.012    -12.388      0.000      -0.176      -0.128
# C(region)[T.Санкт-Петербург г]                              -0.1138      0.022     -5.259      0.000      -0.156      -0.071
# C(region)[T.Саратовская обл]                                 0.0287      0.023      1.269      0.204      -0.016       0.073
# C(region)[T.Саха (Якутия) Респ]                              1.0701      0.132      8.102      0.000       0.811       1.329
# C(region)[T.Свердловская обл]                               -0.2915      0.014    -21.072      0.000      -0.319      -0.264
# C(region)[T.Северная Осетия - Алания Респ]                   0.0274      0.062      0.444      0.657      -0.094       0.148
# C(region)[T.Смоленская обл]                                  0.0933      0.033      2.814      0.005       0.028       0.158
# C(region)[T.Ставропольский край]                            -0.1612      0.022     -7.341      0.000      -0.204      -0.118
# C(region)[T.Тамбовская обл]                                  0.0882      0.033      2.664      0.008       0.023       0.153
# C(region)[T.Татарстан Респ]                                 -0.3457      0.018    -19.701      0.000      -0.380      -0.311
# C(region)[T.Тверская обл]                                    0.0428      0.029      1.455      0.146      -0.015       0.100
# C(region)[T.Томская обл]                                     0.1743      0.042      4.123      0.000       0.091       0.257
# C(region)[T.Тульская обл]                                   -0.0277      0.022     -1.248      0.212      -0.071       0.016
# C(region)[T.Тюменская обл]                                  -0.1951      0.021     -9.513      0.000      -0.235      -0.155
# C(region)[T.Удмуртская Респ]                                -0.0492      0.025     -1.934      0.053      -0.099       0.001
# C(region)[T.Ульяновская обл]                                -0.0439      0.033     -1.333      0.183      -0.108       0.021
# C(region)[T.Хабаровский край]                                0.2307      0.034      6.735      0.000       0.164       0.298
# C(region)[T.Хакасия Респ]                                    1.0173      0.053     19.212      0.000       0.913       1.121
# C(region)[T.Ханты-Мансийский Автономный округ - Югра АО]    -0.4409      0.022    -19.689      0.000      -0.485      -0.397
# C(region)[T.Челябинская обл]                                -0.1932      0.013    -14.874      0.000      -0.219      -0.168
# C(region)[T.Чувашская Республика - Чувашия]                  0.1465      0.034      4.305      0.000       0.080       0.213
# C(region)[T.Ямало-Ненецкий АО]                               0.5479      0.037     15.009      0.000       0.476       0.619
# C(region)[T.Ярославская обл]                                -0.0371      0.027     -1.384      0.166      -0.090       0.015
# log_population                                               0.0659      0.001     55.522      0.000       0.064       0.068
# ria_index                                                    0.0087      0.001      9.890      0.000       0.007       0.010
# ============================================================================================================================
#
# Коэффициент has_school по трафику (лог): 0.09588398232655237

# %% [markdown]
# Если коэффициент `has_school` положительный и значимый (p-value < 0.05),
# это означает: при равных индексе, населении, размере магазина и регионе
# магазины рядом со школой имеют более высокий пешеходный трафик.

# %% [markdown]
# ## Линейная регрессия: средний чек

# %%
check_model = smf.ols(
    formula='log_check ~ has_school + C(size_group) + log_population + ria_index + C(region)',
    data=reg_df,
).fit()

print(check_model.summary().tables[1])
print('\nКоэффициент has_school по чеку (лог):', check_model.params.get('has_school[T.True]', np.nan))
# Out:
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    6.7758      0.031    217.296      0.000       6.715       6.837
# has_school[T.True]                                          -0.0294      0.002    -12.865      0.000      -0.034      -0.025
# C(size_group)[T.medium]                                     -0.1998      0.003    -76.644      0.000      -0.205      -0.195
# C(size_group)[T.small]                                      -0.3414      0.003   -108.483      0.000      -0.348      -0.335
# C(region)[T.Алтай Респ]                                      0.3491      0.045      7.707      0.000       0.260       0.438
# C(region)[T.Алтайский край]                                 -0.1485      0.016     -9.379      0.000      -0.180      -0.117
# C(region)[T.Архангельская обл]                               0.0098      0.019      0.523      0.601      -0.027       0.046
# C(region)[T.Астраханская обл]                               -0.0240      0.018     -1.301      0.193      -0.060       0.012
# C(region)[T.Башкортостан Респ]                              -0.3836      0.007    -57.278      0.000      -0.397      -0.371
# C(region)[T.Белгородская обл]                               -0.0432      0.011     -4.048      0.000      -0.064      -0.022
# C(region)[T.Брянская обл]                                   -0.0030      0.016     -0.190      0.849      -0.034       0.028
# C(region)[T.Владимирская обл]                                0.0139      0.013      1.082      0.279      -0.011       0.039
# C(region)[T.Волгоградская обл]                              -0.2606      0.011    -23.010      0.000      -0.283      -0.238
# C(region)[T.Вологодская обл]                                -0.2162      0.013    -16.072      0.000      -0.243      -0.190
# C(region)[T.Воронежская обл]                                -0.0819      0.008     -9.862      0.000      -0.098      -0.066
# C(region)[T.Еврейская Аобл]                                 -0.8486      0.113     -7.481      0.000      -1.071      -0.626
# C(region)[T.Забайкальский край]                             -0.0605      0.031     -1.940      0.052      -0.122       0.001
# C(region)[T.Ивановская обл]                                 -0.0498      0.018     -2.818      0.005      -0.084      -0.015
# C(region)[T.Иркутская обл]                                  -0.2278      0.015    -15.599      0.000      -0.256      -0.199
# C(region)[T.Кабардино-Балкарская Респ]                      -0.0002      0.045     -0.005      0.996      -0.089       0.088
# C(region)[T.Калининградская обл]                            -0.0262      0.017     -1.538      0.124      -0.060       0.007
# C(region)[T.Калмыкия Респ]                                   0.2626      0.035      7.494      0.000       0.194       0.331
# C(region)[T.Калужская обл]                                   0.1355      0.013     10.043      0.000       0.109       0.162
# C(region)[T.Карачаево-Черкесская Респ]                       0.0997      0.037      2.718      0.007       0.028       0.172
# C(region)[T.Карелия Респ]                                    0.3223      0.021     15.375      0.000       0.281       0.363
# C(region)[T.Кемеровская область - Кузбасс обл]              -0.1631      0.012    -13.719      0.000      -0.186      -0.140
# C(region)[T.Кировская обл]                                  -0.2092      0.016    -13.195      0.000      -0.240      -0.178
# C(region)[T.Коми Респ]                                       0.0003      0.018      0.018      0.985      -0.034       0.035
# C(region)[T.Костромская обл]                                -0.0294      0.022     -1.318      0.187      -0.073       0.014
# C(region)[T.Краснодарский край]                             -0.3643      0.006    -64.944      0.000      -0.375      -0.353
# C(region)[T.Красноярский край]                              -0.3364      0.010    -32.296      0.000      -0.357      -0.316
# C(region)[T.Курганская обл]                                  0.1802      0.024      7.507      0.000       0.133       0.227
# C(region)[T.Курская обл]                                     0.0330      0.014      2.360      0.018       0.006       0.060
# C(region)[T.Ленинградская обл]                              -0.1649      0.008    -20.050      0.000      -0.181      -0.149
# C(region)[T.Липецкая обл]                                   -0.0579      0.011     -5.352      0.000      -0.079      -0.037
# C(region)[T.Марий Эл Респ]                                  -0.0775      0.021     -3.667      0.000      -0.119      -0.036
# C(region)[T.Мордовия Респ]                                  -0.1520      0.021     -7.296      0.000      -0.193      -0.111
# C(region)[T.Москва г]                                       -0.1905      0.011    -17.048      0.000      -0.212      -0.169
# C(region)[T.Московская обл]                                 -0.2168      0.007    -29.339      0.000      -0.231      -0.202
# C(region)[T.Мурманская обл]                                  0.1124      0.015      7.447      0.000       0.083       0.142
# C(region)[T.Нижегородская обл]                              -0.2608      0.006    -41.550      0.000      -0.273      -0.248
# C(region)[T.Новгородская обл]                                0.1256      0.020      6.186      0.000       0.086       0.165
# C(region)[T.Новосибирская обл]                              -0.1594      0.009    -18.452      0.000      -0.176      -0.142
# C(region)[T.Омская обл]                                     -0.1099      0.014     -7.658      0.000      -0.138      -0.082
# C(region)[T.Оренбургская обл]                               -0.2314      0.011    -20.882      0.000      -0.253      -0.210
# C(region)[T.Орловская обл]                                   0.0764      0.019      3.980      0.000       0.039       0.114
# C(region)[T.Пензенская обл]                                 -0.1889      0.016    -11.886      0.000      -0.220      -0.158
# C(region)[T.Пермский край]                                  -0.3438      0.007    -47.892      0.000      -0.358      -0.330
# C(region)[T.Приморский край]                                 0.0640      0.023      2.772      0.006       0.019       0.109
# C(region)[T.Псковская обл]                                   0.2203      0.021     10.665      0.000       0.180       0.261
# C(region)[T.Ростовская обл]                                 -0.3456      0.006    -60.864      0.000      -0.357      -0.335
# C(region)[T.Рязанская обл]                                   0.0457      0.014      3.339      0.001       0.019       0.072
# C(region)[T.Самарская обл]                                  -0.3557      0.006    -59.033      0.000      -0.368      -0.344
# C(region)[T.Санкт-Петербург г]                              -0.1835      0.011    -17.281      0.000      -0.204      -0.163
# C(region)[T.Саратовская обл]                                -0.2420      0.011    -21.807      0.000      -0.264      -0.220
# C(region)[T.Саха (Якутия) Респ]                              0.0637      0.065      0.982      0.326      -0.063       0.191
# C(region)[T.Свердловская обл]                               -0.4268      0.007    -62.880      0.000      -0.440      -0.414
# C(region)[T.Северная Осетия - Алания Респ]                  -0.0529      0.030     -1.748      0.081      -0.112       0.006
# C(region)[T.Смоленская обл]                                  0.0864      0.016      5.308      0.000       0.054       0.118
# C(region)[T.Ставропольский край]                            -0.2399      0.011    -22.261      0.000      -0.261      -0.219
# C(region)[T.Тамбовская обл]                                  0.0191      0.016      1.175      0.240      -0.013       0.051
# C(region)[T.Татарстан Респ]                                 -0.4609      0.009    -53.524      0.000      -0.478      -0.444
# C(region)[T.Тверская обл]                                    0.1389      0.014      9.624      0.000       0.111       0.167
# C(region)[T.Томская обл]                                    -0.0086      0.021     -0.413      0.680      -0.049       0.032
# C(region)[T.Тульская обл]                                   -0.0241      0.011     -2.208      0.027      -0.045      -0.003
# C(region)[T.Тюменская обл]                                  -0.2854      0.010    -28.355      0.000      -0.305      -0.266
# C(region)[T.Удмуртская Респ]                                -0.2211      0.012    -17.708      0.000      -0.246      -0.197
# C(region)[T.Ульяновская обл]                                -0.2072      0.016    -12.828      0.000      -0.239      -0.176
# C(region)[T.Хабаровский край]                               -0.0594      0.017     -3.536      0.000      -0.092      -0.026
# C(region)[T.Хакасия Респ]                                    0.0144      0.026      0.552      0.581      -0.037       0.065
# C(region)[T.Ханты-Мансийский Автономный округ - Югра АО]    -0.3271      0.011    -29.770      0.000      -0.349      -0.306
# C(region)[T.Челябинская обл]                                -0.3473      0.006    -54.496      0.000      -0.360      -0.335
# C(region)[T.Чувашская Республика - Чувашия]                 -0.0766      0.017     -4.588      0.000      -0.109      -0.044
# C(region)[T.Ямало-Ненецкий АО]                              -0.0644      0.018     -3.597      0.000      -0.100      -0.029
# C(region)[T.Ярославская обл]                                -0.1138      0.013     -8.645      0.000      -0.140      -0.088
# log_population                                              -0.0304      0.001    -52.135      0.000      -0.032      -0.029
# ria_index                                                    0.0119      0.000     27.561      0.000       0.011       0.013
# ============================================================================================================================
#
# Коэффициент has_school по чеку (лог): -0.02944253640304881

# %% [markdown]
# Отрицательный и значимый коэффициент `has_school` по `log_check`
# будет означать, что средний чек у магазинов рядом со школой ниже,
# чем у сопоставимых магазинов без школы (при контроле остальных факторов).

# %% [markdown]
# ## Парные сравнения по (НП, size_group)
#
# Теперь сделаем более "интуитивную" проверку:
# - На уровне каждой пары `(Населенный пункт, size_group)` сравниваем средний трафик/чек
#   среди магазинов со школой и без школы.
# - Строим t-тест по разностям.

# %%
from scipy import stats

group_cols = [col_np, 'size_group']

agg = (
    base_df
    .groupby(group_cols + ['has_school'])
    .agg(
        mean_traffic=(col_pedestrian, 'mean'),
        mean_check=(col_check, 'mean'),
        count=('has_school', 'size'),
    )
    .reset_index()
)

pivot_pairs = agg.pivot_table(
    index=group_cols,
    columns='has_school',
    values=['mean_traffic', 'mean_check'],
)

pivot_pairs.columns = [f"{metric}_{'with' if hs else 'without'}" for metric, hs in pivot_pairs.columns]
pivot_pairs = pivot_pairs.dropna().reset_index()

pivot_pairs['diff_traffic'] = pivot_pairs['mean_traffic_with'] - pivot_pairs['mean_traffic_without']
pivot_pairs['diff_check'] = pivot_pairs['mean_check_with'] - pivot_pairs['mean_check_without']

print('Примеры пар:')
pivot_pairs.head()

# %% [markdown]
# ### t-тесты по разностям
#
# Отдельно для small / medium / large_plus считаем t-тесты по разностям
# `with_school - without_school` для трафика и чека.

# %%
alpha = 0.05

for size in ['small', 'medium', 'large_plus']:
    sub = pivot_pairs[pivot_pairs['size_group'] == size]
    if sub.empty:
        print(f"\n[WARN] Нет пар для size_group={size}")
        continue
    dif_tr = sub['diff_traffic'].dropna()
    dif_ch = sub['diff_check'].dropna()
    print(f"\n=== size_group = {size} ===")
    print('Число пар (НП):', len(sub))

    if len(dif_tr) >= 3:
        t_tr, p_tr = stats.ttest_1samp(dif_tr, popmean=0.0)
        print(f"Трафик: mean_diff={dif_tr.mean():.2f}, t={t_tr:.3f}, p={p_tr:.4g}")
        if p_tr < alpha:
            print('→ Разница по трафику статзначима (в среднем у школ трафик иной, чем без школ)')
    else:
        print('Недостаточно пар для трафика')

    if len(dif_ch) >= 3:
        t_ch, p_ch = stats.ttest_1samp(dif_ch, popmean=0.0)
        print(f"Чек: mean_diff={dif_ch.mean():.2f}, t={t_ch:.3f}, p={p_ch:.4g}")
        if p_ch < alpha:
            print('→ Разница по чеку статзначима (в среднем у школ чек иной, чем без школ)')
    else:
        print('Недостаточно пар для чека')
